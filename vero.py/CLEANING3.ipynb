# %%
# Adjust sep=',' or sep=';' depending on your CSV
df_raw = pd.read_csv(
    "Transactions2.csv", 
    sep=',',         # change to ';' if needed
    encoding='cp1252',  # Finnish Excel exports often need cp1252
    dtype=str        # read everything as string first
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Adjust sep=',' or sep=';' depending on your CSV
# ----> 2 df_raw = pd.read_csv(
#       3     "Transactions2.csv",
#       4     sep=',',         # change to ';' if needed
#       5     encoding='cp1252',  # Finnish Excel exports often need cp1252
#       6     dtype=str        # read everything as string first
#       7 )
#
# NameError: name 'pd' is not defined
